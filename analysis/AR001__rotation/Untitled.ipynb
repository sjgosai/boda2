# %%
import pandas as pd

dhsdata = pd.read_csv("gs://haddath/arao/data/sep17strongDHS.tsv", sep='\t')
print(dhsdata)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_78/2835734055.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 dhsdata = pd.read_csv("gs://haddath/arao/data/sep17strongDHS.tsv", sep='\t')
#       4 print(dhsdata)
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
