# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
# Out:
# <style>.container { width:98% !important; }</style>

# %% [markdown]
# # No Penalty

# %%
###K562

# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 0 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 50 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 --n_proposals 2000 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__k562__fsp__track_001__round_0
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpavbjxo7v
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 2000 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-8.75, LR=1e-6]
# finished round
# ...

# %%
###HepG2

# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 1 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 50 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 --n_proposals 2000 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__hepg2__fsp__track_002__round_0
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpd_s9iono
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 2000 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-7.65, LR=1e-6]
# finished round
# ...

# %%
###SKNSH

# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 2 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 50 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 --n_proposals 2000 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__sknsh__fsp__track_003__round_0
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpss_6_7c0
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 2000 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-4.96, LR=1e-6]
# finished round
# ...

# %% [markdown]
# # With Penalty

# %% [markdown]
# ### K562

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 0 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.0 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__k562__fsp__track_004__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpseq6hcov
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.91it/s, Loss=-8.62, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 0 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.0 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__k562__fsp__track_005__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmp_z68603w
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-8.64, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 0 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.0 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__k562__fsp__track_006__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpkh8rgkrf
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-8.66, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 0 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.0 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__k562__fsp__track_007__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpxkf3h4pq
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.93it/s, Loss=-8.81, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %% [markdown]
# ### HepG2

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 1 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__hepg2__fsp__track_008__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpbt952omq
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-7.59, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 1 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__hepg2__fsp__track_009__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpd3n4l2u4
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-7.53, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 1 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__hepg2__fsp__track_010__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpk2d2at_y
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-7.57, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 1 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__hepg2__fsp__track_011__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpmpt8tp7s
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-7.74, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %% [markdown]
# ### SKNSH

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 2 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__sknsh__fsp__track_012__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpl02e60a_
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-4.92, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 2 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__sknsh__fsp__track_013__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmppbz7m9bt
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-4.79, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 2 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__sknsh__fsp__track_014__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpbtj7vqu7
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-4.78, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 2 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__sknsh__fsp__track_015__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmpc7muouf3
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.92it/s, Loss=-4.88, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %% [markdown]
# # Extras

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 0 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.2 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.0 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__k562__fsp__track_006__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmp1gpxtyj7
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.93it/s, Loss=-8.73, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 0 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.2 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.0 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__k562__fsp__track_007__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmp88tpmyxx
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.93it/s, Loss=-8.46, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...

# %%
# !python /home/ubuntu/boda2/src/generate.py --params_module StraightThroughParameters --batch_size 64 \
    --n_channels 4 --length 200 --n_samples 20 --energy_module OverMaxEnergy \
    --model_artifact gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz --bias_cell 2 \
    --bending_factor 1.0 --a_min -2.0 --a_max 6.0 --generator_module FastSeqProp --energy_threshold -3.6 \
    --max_attempts 20 --n_steps 300 --penalty_module StremePenalty --score_pct 0.25 \
    --n_proposals 500 250 250 250 250 250 \
    --proposal_path gs://syrgoth/boda_library_design_202112/extra_pickles_2/rc__sknsh__fsp__track_012__round_5
# Out:
# Copying gs://syrgoth/aip_ui_test/model_artifacts__20211113_021200__287348.tar.gz...
# - [1 files][ 49.3 MiB/ 49.3 MiB]
# Operation completed over 1 objects/49.3 MiB.
# archive unpacked in /tmp/tmp9572n7h6
# Loaded model from 20211113_021200 in eval mode
# Starting round: 0, generate 500 proposals
# Steps:   0%|                                            | 0/300 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:652: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool1d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...
# Steps: 100%|█████████████| 300/300 [00:37<00:00,  7.96it/s, Loss=-4.97, LR=1e-6]
# finished round
# Starting round: 1, generate 250 proposals
# ...
